# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from scipy import signal
import pywt

# %%
data = pd.read_excel('../data/pressure raw/stratified/0.5/50/run1.xlsx')

# %%
data
# Out:
#        TIME  AXIS    - Plot 0  \
# 0           1009782:42:44.155
# 1           1009782:42:44.156
# 2           1009782:42:44.157
# 3           1009782:42:44.158
# 4           1009782:42:44.159
# ...                       ...
# 165998      1009782:46:01.720
# 165999      1009782:46:01.721
# 166000                    NaN
# 166001                    NaN
# 166002                    NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 0  \
# 0                                                0.015230
# 1                                                0.015970
# 2                                                0.015720
# 3                                                0.016210
# 4                                                0.015230
# ...                                                   ...
# 165998                                           0.016210
# 165999                                           0.016210
# 166000                                           0.016035
# 166001                                                NaN
# 166002                                                NaN
#
#        TIME  AXIS    - Plot 1  \
# 0           1009782:42:44.155
# 1           1009782:42:44.156
# 2           1009782:42:44.157
# 3           1009782:42:44.158
# 4           1009782:42:44.159
# ...                       ...
# 165998      1009782:46:01.720
# 165999      1009782:46:01.721
# 166000                    NaN
# 166001                    NaN
# 166002                    NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 1  \
# 0                                                0.016940
# 1                                                0.016940
# 2                                                0.016940
# 3                                                0.016460
# 4                                                0.016460
# ...                                                   ...
# 165998                                           0.016210
# 165999                                           0.011820
# 166000                                           0.016842
# 166001                                                NaN
# 166002                                                NaN
#
#        TIME  AXIS    - Plot 2  \
# 0           1009782:42:44.155
# 1           1009782:42:44.156
# 2           1009782:42:44.157
# 3           1009782:42:44.158
# 4           1009782:42:44.159
# ...                       ...
# 165998      1009782:46:01.720
# 165999      1009782:46:01.721
# 166000                    NaN
# 166001                    NaN
# 166002                    NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 2  \
# 0                                                0.017190
# 1                                                0.016460
# 2                                                0.015970
# 3                                                0.016940
# 4                                                0.017190
# ...                                                   ...
# 165998                                           0.016700
# 165999                                           0.016940
# 166000                                           0.016588
# 166001                                                NaN
# 166002                                                NaN
#
#        TIME  AXIS    - Plot 3  \
# 0           1009782:42:44.155
# 1           1009782:42:44.156
# 2           1009782:42:44.157
# 3           1009782:42:44.158
# 4           1009782:42:44.159
# ...                       ...
# 165998      1009782:46:01.720
# 165999      1009782:46:01.721
# 166000                    NaN
# 166001                    NaN
# 166002                    NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 3  \
# 0                                                0.015970
# 1                                                0.016210
# 2                                                0.016210
# 3                                                0.015480
# 4                                                0.016210
# ...                                                   ...
# 165998                                           0.015480
# 165999                                           0.015480
# 166000                                           0.015439
# 166001                                                NaN
# 166002                                                NaN
#
#        TIME  AXIS    - Plot 4  \
# 0           1009782:42:44.155
# 1           1009782:42:44.156
# 2           1009782:42:44.157
# 3           1009782:42:44.158
# 4           1009782:42:44.159
# ...                       ...
# 165998      1009782:46:01.720
# 165999      1009782:46:01.721
# 166000                    NaN
# 166001                    NaN
# 166002                    NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 4  \
# 0                                                0.016210
# 1                                                0.016460
# 2                                                0.015720
# 3                                                0.015720
# 4                                                0.015720
# ...                                                   ...
# 165998                                           0.013280
# 165999                                           0.016210
# 166000                                           0.015831
# 166001                                                NaN
# 166002                                                NaN
#
#        TIME  AXIS    - Plot 5  \
# 0           1009782:42:44.155
# 1           1009782:42:44.156
# 2           1009782:42:44.157
# 3           1009782:42:44.158
# 4           1009782:42:44.159
# ...                       ...
# 165998      1009782:46:01.720
# 165999      1009782:46:01.721
# 166000                    NaN
# 166001                    NaN
# 166002                    NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 5
# 0                                                0.014750
# 1                                                0.015230
# 2                                                0.015230
# 3                                                0.017920
# 4                                                0.014260
# ...                                                   ...
# 165998                                           0.015230
# 165999                                           0.015480
# 166000                                           0.014951
# 166001                                           0.001084
# 166002                                           0.013548
#
# [166003 rows x 12 columns]

# %%
data.columns
# Out:
# Index(['TIME  AXIS    - Plot 0',
#        'PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 0',
#        'TIME  AXIS    - Plot 1',
#        'PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 1',
#        'TIME  AXIS    - Plot 2',
#        'PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 2',
#        'TIME  AXIS    - Plot 3',
#        'PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 3',
#        'TIME  AXIS    - Plot 4',
#        'PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 4',
#        'TIME  AXIS    - Plot 5',
#        'PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 5'],
#       dtype='object')

# %%
# type(data['TIME  AXIS    - Plot 0'])

# %%
# data.set_index('TIME  AXIS    - Plot 0',inplace=True)

# %%
data.drop(['TIME  AXIS    - Plot 0',
           'TIME  AXIS    - Plot 1',
           'TIME  AXIS    - Plot 2',
           'TIME  AXIS    - Plot 3',
           'TIME  AXIS    - Plot 4',
           'TIME  AXIS    - Plot 5'],axis=1,inplace=True)

# %%
data
# Out:
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 0  \
# 0                                                0.015230
# 1                                                0.015970
# 2                                                0.015720
# 3                                                0.016210
# 4                                                0.015230
# ...                                                   ...
# 165998                                           0.016210
# 165999                                           0.016210
# 166000                                           0.016035
# 166001                                                NaN
# 166002                                                NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 1  \
# 0                                                0.016940
# 1                                                0.016940
# 2                                                0.016940
# 3                                                0.016460
# 4                                                0.016460
# ...                                                   ...
# 165998                                           0.016210
# 165999                                           0.011820
# 166000                                           0.016842
# 166001                                                NaN
# 166002                                                NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 2  \
# 0                                                0.017190
# 1                                                0.016460
# 2                                                0.015970
# 3                                                0.016940
# 4                                                0.017190
# ...                                                   ...
# 165998                                           0.016700
# 165999                                           0.016940
# 166000                                           0.016588
# 166001                                                NaN
# 166002                                                NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 3  \
# 0                                                0.015970
# 1                                                0.016210
# 2                                                0.016210
# 3                                                0.015480
# 4                                                0.016210
# ...                                                   ...
# 165998                                           0.015480
# 165999                                           0.015480
# 166000                                           0.015439
# 166001                                                NaN
# 166002                                                NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 4  \
# 0                                                0.016210
# 1                                                0.016460
# 2                                                0.015720
# 3                                                0.015720
# 4                                                0.015720
# ...                                                   ...
# 165998                                           0.013280
# 165999                                           0.016210
# 166000                                           0.015831
# 166001                                                NaN
# 166002                                                NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 5
# 0                                                0.014750
# 1                                                0.015230
# 2                                                0.015230
# 3                                                0.017920
# 4                                                0.014260
# ...                                                   ...
# 165998                                           0.015230
# 165999                                           0.015480
# 166000                                           0.014951
# 166001                                           0.001084
# 166002                                           0.013548
#
# [166003 rows x 6 columns]

# %%
data.dropna(inplace=True)
data
# Out:
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 0  \
# 0                                                0.015230
# 1                                                0.015970
# 2                                                0.015720
# 3                                                0.016210
# 4                                                0.015230
# ...                                                   ...
# 165996                                           0.015480
# 165997                                           0.021090
# 165998                                           0.016210
# 165999                                           0.016210
# 166000                                           0.016035
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 1  \
# 0                                                0.016940
# 1                                                0.016940
# 2                                                0.016940
# 3                                                0.016460
# 4                                                0.016460
# ...                                                   ...
# 165996                                           0.017190
# 165997                                           0.016940
# 165998                                           0.016210
# 165999                                           0.011820
# 166000                                           0.016842
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 2  \
# 0                                                0.017190
# 1                                                0.016460
# 2                                                0.015970
# 3                                                0.016940
# 4                                                0.017190
# ...                                                   ...
# 165996                                           0.011570
# 165997                                           0.016460
# 165998                                           0.016700
# 165999                                           0.016940
# 166000                                           0.016588
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 3  \
# 0                                                0.015970
# 1                                                0.016210
# 2                                                0.016210
# 3                                                0.015480
# 4                                                0.016210
# ...                                                   ...
# 165996                                           0.015480
# 165997                                           0.014260
# 165998                                           0.015480
# 165999                                           0.015480
# 166000                                           0.015439
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 4  \
# 0                                                0.016210
# 1                                                0.016460
# 2                                                0.015720
# 3                                                0.015720
# 4                                                0.015720
# ...                                                   ...
# 165996                                           0.015720
# 165997                                           0.014750
# 165998                                           0.013280
# 165999                                           0.016210
# 166000                                           0.015831
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 5
# 0                                                0.014750
# 1                                                0.015230
# 2                                                0.015230
# 3                                                0.017920
# 4                                                0.014260
# ...                                                   ...
# 165996                                           0.014010
# 165997                                           0.015230
# 165998                                           0.015230
# 165999                                           0.015480
# 166000                                           0.014951
#
# [166001 rows x 6 columns]

# %% [markdown]
# ## Raw data

# %%
len(data.index)
# Out:
# 166001

# %%
sen4 = data['PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 4']
time = data.index

# %%
fig, ax = plt.subplots(3, 3, figsize=(20, 16))

time_slices = [(i, i+20000) for i in range(0, 180000, 20000)]
for i, (start, end) in enumerate(time_slices):
    row = i // 3
    col = i % 3
    ax[row, col].plot(time[start:end], sen4[start:end])
    ax[row, col].set_title(f'{start} - {end} millisec')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Smoothing Signal

# %%
sen4_smooth = signal.savgol_filter(data['PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 4'],21,3)
time = data.index

# %%
fig, ax = plt.subplots(3, 3, figsize=(20, 16))

time_slices = [(i, i+20000) for i in range(0, 180000, 20000)]
for i, (start, end) in enumerate(time_slices):
    row = i // 3
    col = i % 3
    ax[row, col].plot(time[start:end], sen4_smooth[start:end])
    ax[row, col].set_title(f'{start} - {end} millisec')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(3, 3, figsize=(20, 16))

time_slices = [(i, i+20000) for i in range(0, 180000, 20000)]
for i, (start, end) in enumerate(time_slices):
    row = i // 3
    col = i % 3
    ax[row, col].plot(time[start:end], signal.detrend(sen4_smooth[start:end]),color='firebrick',label='Detrended Signal')
    ax[row, col].plot(time[start:end], sen4_smooth[start:end],color='navy',label='Raw Signal')
    ax[row, col].set_title(f'{start} - {end} millisec')

plt.tight_layout()
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
fig, ax = plt.subplots(3, 3, figsize=(20, 16))

time_slices = [(i, i+20000) for i in range(0, 180000, 20000)]
for i, (start, end) in enumerate(time_slices):
    row = i // 3
    col = i % 3
#     ax[row, col].plot(time[start:end], sen4[start:end])
#     ax[row, col].set_title(f'{start} - {end} millisec')
    
    sen4_detrend = signal.detrend(sen4[start:end])
    n = len(sen4_detrend)
    f_hat = np.fft.fft(sen4_detrend, n)
    PSD = f_hat*np.conj(f_hat)/n
    L = np.arange(1,np.floor(n/2), dtype='int')
    freq = np.arange(n)

    ax[row, col].plot(freq[L],PSD[L], color='c')
    plt.xlim(0,500)
    

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(3, 3, figsize=(20, 16))

time_slices = [(i, i+20000) for i in range(0, 180000, 20000)]
for i, (start, end) in enumerate(time_slices):
    row = i // 3
    col = i % 3
    widths = np.arange(1, 31)
    cwtmatr, freqs = pywt.cwt(signal.detrend(sen4_smooth[start:end]), widths, 'mexh')
    ax[row,col].imshow(cwtmatr, extent=[-1, 1, 1, 31], cmap='PRGn', aspect='auto',
           vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max()) 

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(3, 3, figsize=(20,16))

time_slices = [(i, i+20000) for i in range(0, 180000, 20000)]
for i, (start, end) in enumerate(time_slices):
    row = i // 3
    col = i % 3
    widths = np.arange(1, 31)
    cwtmatr, freqs = pywt.cwt(signal.detrend(sen4_smooth[start:end]), widths, 'mexh')
    ax[row,col].imshow(np.absolute(cwtmatr), extent=[-1, 1, 1, 31], cmap='PRGn', aspect='auto',
           vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max()) 

plt.tight_layout()
plt.show()
