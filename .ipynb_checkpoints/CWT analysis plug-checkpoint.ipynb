                    NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 5
# 0                                                0.017190
# 1                                                0.015480
# 2                                                0.016940
# 3                                                0.017430
# 4                                                0.016210
# ...                                                   ...
# 163998                                           0.016460
# 163999                                           0.020610
# 164000                                           0.016223
# 164001                                           0.002123
# 164002                                           0.026536
#
# [164003 rows x 12 columns]

# %%
data.columns
# Out:
# Index(['TIME  AXIS    - Plot 0',
#        'PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 0',
#        'TIME  AXIS    - Plot 1',
#        'PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 1',
#        'TIME  AXIS    - Plot 2',
#        'PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 2',
#        'TIME  AXIS    - Plot 3',
#        'PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 3',
#        'TIME  AXIS    - Plot 4',
#        'PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 4',
#        'TIME  AXIS    - Plot 5',
#        'PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 5'],
#       dtype='object')

# %%
# type(data['TIME  AXIS    - Plot 0'])

# %%
# data.set_index('TIME  AXIS    - Plot 0',inplace=True)

# %%
data.drop(['TIME  AXIS    - Plot 0',
           'TIME  AXIS    - Plot 1',
           'TIME  AXIS    - Plot 2',
           'TIME  AXIS    - Plot 3',
           'TIME  AXIS    - Plot 4',
           'TIME  AXIS    - Plot 5'],axis=1,inplace=True)

# %%
data
# Out:
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 0  \
# 0                                                0.016210
# 1                                                0.017190
# 2                                                0.018650
# 3                                                0.018410
# 4                                                0.019140
# ...                                                   ...
# 163998                                           0.019380
# 163999                                           0.019630
# 164000                                           0.018346
# 164001                                                NaN
# 164002                                                NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 1  \
# 0                                                0.018410
# 1                                                0.018650
# 2                                                0.018650
# 3                                                0.018900
# 4                                                0.018160
# ...                                                   ...
# 163998                                           0.015230
# 163999                                           0.018160
# 164000                                           0.018329
# 164001                                                NaN
# 164002                                                NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 2  \
# 0                                                0.017680
# 1                                                0.018160
# 2                                                0.017920
# 3                                                0.017920
# 4                                                0.017680
# ...                                                   ...
# 163998                                           0.017920
# 163999                                           0.017430
# 164000                                           0.017715
# 164001                                                NaN
# 164002                                                NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 3  \
# 0                                                0.017430
# 1                                                0.017920
# 2                                                0.017190
# 3                                                0.016700
# 4                                                0.016460
# ...                                                   ...
# 163998                                           0.016460
# 163999                                           0.016700
# 164000                                           0.016516
# 164001                                                NaN
# 164002                                                NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 4  \
# 0                                                0.018160
# 1                                                0.017680
# 2                                                0.017430
# 3                                                0.017190
# 4                                                0.016940
# ...                                                   ...
# 163998                                           0.019380
# 163999                                           0.015970
# 164000                                           0.017483
# 164001                                                NaN
# 164002                                                NaN
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 5
# 0                                                0.017190
# 1                                                0.015480
# 2                                                0.016940
# 3                                                0.017430
# 4                                                0.016210
# ...                                                   ...
# 163998                                           0.016460
# 163999                                           0.020610
# 164000                                           0.016223
# 164001                                           0.002123
# 164002                                           0.026536
#
# [164003 rows x 6 columns]

# %%
data.dropna(inplace=True)
data
# Out:
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 0  \
# 0                                                0.016210
# 1                                                0.017190
# 2                                                0.018650
# 3                                                0.018410
# 4                                                0.019140
# ...                                                   ...
# 163996                                           0.019870
# 163997                                           0.019380
# 163998                                           0.019380
# 163999                                           0.019630
# 164000                                           0.018346
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 1  \
# 0                                                0.018410
# 1                                                0.018650
# 2                                                0.018650
# 3                                                0.018900
# 4                                                0.018160
# ...                                                   ...
# 163996                                           0.017920
# 163997                                           0.017920
# 163998                                           0.015230
# 163999                                           0.018160
# 164000                                           0.018329
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 2  \
# 0                                                0.017680
# 1                                                0.018160
# 2                                                0.017920
# 3                                                0.017920
# 4                                                0.017680
# ...                                                   ...
# 163996                                           0.020360
# 163997                                           0.017430
# 163998                                           0.017920
# 163999                                           0.017430
# 164000                                           0.017715
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 3  \
# 0                                                0.017430
# 1                                                0.017920
# 2                                                0.017190
# 3                                                0.016700
# 4                                                0.016460
# ...                                                   ...
# 163996                                           0.016460
# 163997                                           0.016700
# 163998                                           0.016460
# 163999                                           0.016700
# 164000                                           0.016516
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 4  \
# 0                                                0.018160
# 1                                                0.017680
# 2                                                0.017430
# 3                                                0.017190
# 4                                                0.016940
# ...                                                   ...
# 163996                                           0.017190
# 163997                                           0.019630
# 163998                                           0.019380
# 163999                                           0.015970
# 164000                                           0.017483
#
#         PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 5
# 0                                                0.017190
# 1                                                0.015480
# 2                                                0.016940
# 3                                                0.017430
# 4                                                0.016210
# ...                                                   ...
# 163996                                           0.016700
# 163997                                           0.015970
# 163998                                           0.016460
# 163999                                           0.020610
# 164000                                           0.016223
#
# [164001 rows x 6 columns]

# %% [markdown]
# ## Raw data

# %%
len(data.index)
# Out:
# 164001

# %%
sen4 = data['PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 4']
time = data.index

# %%
fig, ax = plt.subplots(3, 3, figsize=(20, 16))

time_slices = [(i, i+20000) for i in range(0, 180000, 20000)]
for i, (start, end) in enumerate(time_slices):
    row = i // 3
    col = i % 3
    ax[row, col].plot(time[start:end], sen4[start:end])
    ax[row, col].set_title(f'{start} - {end} millisec')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Smoothing Signal

# %%
sen4_smooth = signal.savgol_filter(data['PRESSURE    AXIS    RANGE  0- 0.1 BAR      - Plot 4'],21,3)
time = data.index

# %%
fig, ax = plt.subplots(3, 3, figsize=(20, 16))

time_slices = [(i, i+20000) for i in range(0, 180000, 20000)]
for i, (start, end) in enumerate(time_slices):
    row = i // 3
    col = i % 3
    ax[row, col].plot(time[start:end], sen4_smooth[start:end])
    ax[row, col].set_title(f'{start} - {end} millisec')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(3, 3, figsize=(20, 16))

time_slices = [(i, i+20000) for i in range(0, 180000, 20000)]
for i, (start, end) in enumerate(time_slices):
    row = i // 3
    col = i % 3
    ax[row, col].plot(time[start:end], signal.detrend(sen4_smooth[start:end]),color='firebrick',label='Detrended Signal')
    ax[row, col].plot(time[start:end], sen4_smooth[start:end],color='navy',label='Raw Signal')
    ax[row, col].set_title(f'{start} - {end} millisec')

plt.tight_layout()
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
fig, ax = plt.subplots(3, 3, figsize=(20, 16))

time_slices = [(i, i+20000) for i in range(0, 180000, 20000)]
for i, (start, end) in enumerate(time_slices):
    row = i // 3
    col = i % 3
#     ax[row, col].plot(time[start:end], sen4[start:end])
#     ax[row, col].set_title(f'{start} - {end} millisec')
    
    sen4_detrend = signal.detrend(sen4[start:end])
    n = len(sen4_detrend)
    f_hat = np.fft.fft(sen4_detrend, n)
    PSD = f_hat*np.conj(f_hat)/n
    L = np.arange(1,np.floor(n/2), dtype='int')
    freq = np.arange(n)

    ax[row, col].plot(freq[L],PSD[L], color='c')
    plt.xlim(0,500)
    

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(3, 3, figsize=(20, 16))

time_slices = [(i, i+20000) for i in range(0, 180000, 20000)]
for i, (start, end) in enumerate(time_slices):
    row = i // 3
    col = i % 3
    widths = np.arange(1, 31)
    cwtmatr, freqs = pywt.cwt(signal.detrend(sen4_smooth[start:end]), widths, 'mexh')
    ax[row,col].imshow(cwtmatr, extent=[-1, 1, 1, 31], cmap='PRGn', aspect='auto',
           vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max()) 

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(3, 3, figsize=(20,16))

time_slices = [(i, i+20000) for i in range(0, 180000, 20000)]
for i, (start, end) in enumerate(time_slices):
    row = i // 3
    col = i % 3
    widths = np.arange(1, 31)
    cwtmatr, freqs = pywt.cwt(signal.detrend(sen4_smooth[start:end]), widths, 'mexh')
    ax[row,col].imshow(np.absolute(cwtmatr), extent=[-1, 1, 1, 31], cmap='PRGn', aspect='auto',
           vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max()) 

plt.tight_layout()
plt.show()
